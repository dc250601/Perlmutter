# %%
import numpy as np
import einops
import torch
import torchvision
import matplotlib.pyplot as plt

# %%
img = plt.imread("./data/Raw-Data/Tau_Dataset/Test/0/1.png")
img = einops.rearrange(img, 'h ( w c ) -> c h w ', w = 125, c=13)

# %%
tensor = torch.tensor(img)

# %%
rot = torchvision.transforms.RandomRotation(40)(tensor)

# %%
plt.imshow(tensor.numpy()[6,:,:])

# %%
plt.imshow(rot.numpy()[6,:,:])

# %%
# !pip list
